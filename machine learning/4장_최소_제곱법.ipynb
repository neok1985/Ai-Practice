# %%
import numpy as np
x=np.array([2,4,6,8])
y=np.array([81,93,91,97])

# %%
mx=np.mean(x)
my=np.mean(y)
divisor=sum([(i-mx)**2 for i in x])
def top(x,mx,y,my):
  d=0
  for i in range(len(x)):
    d+=(x[i]-mx)*(y[i]-my)
  return d
dividend=top(x,mx,y,my)

# %%
a=dividend/divisor
b=my-(mx*a)

# %%
print('x의 평균값: ',mx)
print('y의 평균값: ',my)
print('\n')
print('분모: ',divisor)
print('분자: ',dividend)
print('\n')
print('기울기 a= ',a)
print('y절편 b= ',b)
# Out:
# x의 평균값:  5.0
# y의 평균값:  90.5
#
#
# 분모:  20.0
# 분자:  46.0
#
#
# 기울기 a=  2.3
# y절편 b=  79.0

# %% [markdown]
# # ***평균 제곱 오차***

# %%
fake_a=3
fake_b=76
def predict(x):
  return fake_a*x+fake_b

predict_result=[]
for i in range(len(x)):
  predict_result.append(predict(x[i]))
  print('공부시간=%.f,실제점수=%.f,예측점수=%.f'%(x[i],y[i],predict(x[i])))
n=len(x)
def mse(y,y_pred):
  return (1/n)*sum((y-y_pred)**2)
print()
print('평균 제곱 오차:'+str(mse(y,predict_result)))
# Out:
# 공부시간=2,실제점수=81,예측점수=82
# 공부시간=4,실제점수=93,예측점수=88
# 공부시간=6,실제점수=91,예측점수=94
# 공부시간=8,실제점수=97,예측점수=100
#
# 평균 제곱 오차:11.0

# %% [markdown]
# # ***선형 회귀 모델***

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

# %%
a=0
b=0
lr=0.03
epochs=2001
n=len(x)
for i in range(epochs):
  y_pred=a*x+b
  error=y-y_pred
  a_diff=(2/n)*sum(-x*(error))
  b_diff=(2/n)*sum(-(error))
  a=a-lr*a_diff
  b=b-lr*b_diff
  if i%100==0:
    print('epoch=%.f,기울기=%.04f,절편=%.04f'%(i,a,b))
y_pred=a*x+b
plt.scatter(x,y)
plt.plot(x,y_pred,'r')
plt.show()
# Out:
# epoch=0,기울기=27.8400,절편=5.4300
# epoch=100,기울기=7.0739,절편=50.5117
# epoch=200,기울기=4.0960,절편=68.2822
# epoch=300,기울기=2.9757,절편=74.9678
# epoch=400,기울기=2.5542,절편=77.4830
# epoch=500,기울기=2.3956,절편=78.4293
# epoch=600,기울기=2.3360,절편=78.7853
# epoch=700,기울기=2.3135,절편=78.9192
# epoch=800,기울기=2.3051,절편=78.9696
# epoch=900,기울기=2.3019,절편=78.9886
# epoch=1000,기울기=2.3007,절편=78.9957
# epoch=1100,기울기=2.3003,절편=78.9984
# epoch=1200,기울기=2.3001,절편=78.9994
# epoch=1300,기울기=2.3000,절편=78.9998
# epoch=1400,기울기=2.3000,절편=78.9999
# epoch=1500,기울기=2.3000,절편=79.0000
# epoch=1600,기울기=2.3000,절편=79.0000
# epoch=1700,기울기=2.3000,절편=79.0000
# epoch=1800,기울기=2.3000,절편=79.0000
# epoch=1900,기울기=2.3000,절편=79.0000
# epoch=2000,기울기=2.3000,절편=79.0000

# %% [markdown]
# # ***다중 선형 회귀***

# %%
x1=np.array([2,4,6,8])
x2=np.array([0,4,2,3])
y=np.array([81,93,91,97])
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter3D(x1,x2,y);
plt.show()
a1=0
a2=0
b=0
lr=0.01
epochs=2001

# %%
y_pred=a1*x1+a2*x2+b
error=y-y_pred
n=len(x1)
a1_diff=(2/n)*sum(-x1*(error))
a2_diff=(2/n)*sum(-x2*(error))
b_diff=(2/n)*sum(-(error))
a1=a1-lr*a1_diff
a2=a2-lr*a2_diff
b=b-lr*b_diff

# %%
for i in range(epochs):
  y_pred=a1*x1+a2*x2+b
  error=y-y_pred
  a1_diff=(2/n)*sum(-x1*(error))
  a2_diff=(2/n)*sum(-x2*(error))
  b_diff=(2/n)*sum(-(error))
  a1=a1-lr*a1_diff
  a2=a2-lr*a2_diff
  b=b-lr*b_diff
  if i %100==0:
    print('epoch=%.f,기울기1=%.04f,기울기2=%.04f,절편=%.04f'%(i,a1,a2,b))


print('실제 점수: ',y)
print('예측 점수: ',y_pred)
# Out:
# epoch=0,기울기1=11.7125,기울기2=5.3431,절편=2.4657
# epoch=100,기울기1=9.4853,기울기2=5.0188,절편=23.0947
# epoch=200,기울기1=7.3053,기울기2=4.2886,절편=38.0019
# epoch=300,기울기1=5.7246,기울기2=3.7443,절편=48.8512
# epoch=400,기울기1=4.5746,기울기2=3.3473,절편=56.7472
# epoch=500,기울기1=3.7376,기울기2=3.0583,절편=62.4937
# epoch=600,기울기1=3.1285,기울기2=2.8480,절편=66.6759
# epoch=700,기울기1=2.6852,기울기2=2.6949,절편=69.7197
# epoch=800,기울기1=2.3626,기울기2=2.5835,절편=71.9349
# epoch=900,기울기1=2.1277,기울기2=2.5025,절편=73.5470
# epoch=1000,기울기1=1.9569,기울기2=2.4435,절편=74.7203
# epoch=1100,기울기1=1.8325,기울기2=2.4005,절편=75.5742
# epoch=1200,기울기1=1.7420,기울기2=2.3693,절편=76.1957
# epoch=1300,기울기1=1.6761,기울기2=2.3465,절편=76.6480
# epoch=1400,기울기1=1.6282,기울기2=2.3300,절편=76.9771
# epoch=1500,기울기1=1.5933,기울기2=2.3179,절편=77.2167
# epoch=1600,기울기1=1.5679,기울기2=2.3092,절편=77.3910
# epoch=1700,기울기1=1.5494,기울기2=2.3028,절편=77.5179
# epoch=1800,기울기1=1.5360,기울기2=2.2981,절편=77.6103
# epoch=1900,기울기1=1.5262,기울기2=2.2947,절편=77.6775
# epoch=2000,기울기1=1.5190,기울기2=2.2923,절편=77.7264
# ...

# %% [markdown]
# # ***텐서 플로에서 실행하는 선형회귀,다중 선형회귀 모델***

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

model.add(Dense(1,input_dim=1,activation='linear'))
model.compile(optimizer='sgd',loss='mse')
model.fit(x,y,epochs=2000)

plt.scatter(x,y)
plt.plot(x,model.predict(x),'r')
plt.show()

hour=7
prediction=model.predict([hour])
print('%.f 시간을 공부할 경우의 예상 점수는 %.02f점입니다.'%(hour,prediction))
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 486ms/step - loss: 7722.1025
# Epoch 2/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 1968.4252
# Epoch 3/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 1117.9980
# Epoch 4/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 987.7703
# Epoch 5/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 963.3562
# Epoch 6/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 954.5179
# Epoch 7/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 948.0013
# Epoch 8/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 941.8594
# Epoch 9/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 935.8062
# Epoch 10/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 929.7994
# Epoch 11/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 923.8325
# Epoch 12/2000
# ...

# %% [markdown]
# # ***텐서 플로에서 다중 회귀***

# %%
x=np.array([[2,0],[4,4],[6,2],[8,3]])
y=np.array([81,93,91,97])

model=Sequential()

model.add(Dense(1,input_dim=2,activation='linear'))
model.compile(optimizer='sgd',loss='mse')
model.fit(x,y,epochs=2000)

# plt.scatter(x,y)
# plt.plot(x,model.predict(x),'r')
# plt.show()
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 531ms/step - loss: 8614.8311
# Epoch 2/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 1465.7832
# Epoch 3/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 957.4935
# Epoch 4/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 916.2845
# Epoch 5/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 907.9625
# Epoch 6/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 901.9899
# Epoch 7/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 896.2192
# Epoch 8/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 890.4988
# Epoch 9/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 884.8177
# Epoch 10/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 879.1748
# Epoch 11/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 873.5696
# Epoch 12/2000
# ...

# %%
hour=7
private_class=4
prediction=model.predict([[hour,private_class]])
print('%.f 시간을 공부하고 %.f시간의 과외를 받을 경우, 예상 점수는 %.02f점입니다.'%(hour,private_class,prediction))
# Out:
# 7 시간을 공부하고 4시간의 과외를 받을 경우, 예상 점수는 97.53점입니다.

# %%
l_x=np.array([2,4,6,8,10,12,14])
l_y=np.array([0,0,0,1,1,1,1])

model=Sequential()

model.add(Dense(1,input_dim=1,activation='sigmoid'))
model.compile(optimizer='sgd',loss='binary_crossentropy')
model.fit(l_x, l_y, epochs=5000)

plt.scatter(l_x,l_y)
plt.plot(l_x,model.predict(l_x),'r')
plt.show()

hour=7
prediction=model.predict([hour])
print('%.f 시간을 공부할 경우의 예상 확률은 %.02f%%점입니다.'%(hour,prediction*100))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2648
# Epoch 2502/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2647
# Epoch 2503/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2647
# Epoch 2504/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2646
# Epoch 2505/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2646
# Epoch 2506/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2645
# Epoch 2507/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2645
# Epoch 2508/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2644
# Epoch 2509/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2644
# Epoch 2510/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2643
# Epoch 2511/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2643
# Epoch 2512/5000
# ...
